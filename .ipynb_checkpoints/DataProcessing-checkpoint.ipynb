# %% [markdown]
# # Data Processing
# *File Started*: November 11, 2025 <br>
# *Developers*: Rachael & Emily
#
# This `.ipynb` file will contain all of the data processing of the raw data files.

# %%
# ===============================
# imports
# ===============================

import pandas as pd
import numpy as np
import h5py
import xarray as xr
import os.path

# %% [markdown]
# ## Lightning Data

# %% [markdown]
# Lightning data was retrieved from the International Space Station Monthly Timeseries Dataset.

# %%
# ===============================
# load in data
# ===============================

# file paths
ltg_ydts_path = '/shared_space/FireMap/raw_data/lightning/ISSYearlyDiurnalTimeSeries.hdf'
ltg_dc_path = '/shared_space/FireMap/raw_data/lightning/ISSDiurnalCycle.hdf'
ltg_adc_path = '/shared_space/FireMap/raw_data/lightning/ISSAnnualDiurnalCycle.hdf'
ltg_mts_path = '/shared_space/FireMap/raw_data/lightning/ISSMonthlyTimeSeries.hdf'

# load in files
ltg_ydts = xr.open_dataset(ltg_ydts_path, engine="netcdf4")
ltg_dc = xr.open_dataset(ltg_dc_path, engine="netcdf4")
ltg_adc = xr.open_dataset(ltg_adc_path, engine="netcdf4")
ltg_mts = xr.open_dataset(ltg_mts_path, engine="netcdf4")

# %%
# ===============================
# view structure
# ===============================

ltg_mts
# Out:
# <xarray.Dataset>
# Dimensions:                       (Latitude: 72, Latitude_vt: 72, Longitude: 144, Longitude_vt: 144, Month: 84)
# Coordinates:
#   * Month                         (Month) float32 0.0 2.0 3.0 ... 82.0 83.0 0.0
#   * Longitude                     (Longitude) float32 -178.75 -176.25 ... 178.75
#   * Latitude                      (Latitude) float32 -88.75 -86.25 ... 88.75
#   * Longitude_vt                  (Longitude_vt) float32 -178.75 ... 178.75
#   * Latitude_vt                   (Latitude_vt) float32 -88.75 -86.25 ... 88.75
# Data variables:
#     flashcount_raw                (Latitude, Longitude, Month) int32 ...
#     flashcount_scaled             (Latitude, Longitude, Month) float32 ...
#     flashrate                     (Latitude, Longitude, Month) float32 ...
#     viewtime                      (Latitude, Longitude, Month) timedelta64[ns] ...
#     grid_areas                    (Latitude, Longitude) float32 ...
# ...
